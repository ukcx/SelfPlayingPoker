# %%
# %pip install numpy
# %pip install torch
# %pip install stable-baselines3
# %pip install tensorflow-gpu
# %pip install shimmy

# %%
class Card:
    def __init__(self, rank, suit):
        self.rank = rank
        self.suit = suit

    def __repr__(self):
        suits = {
            "S": "♠",
            "H": "♥",
            "D": "♦",
            "C": "♣",
        }
        ranks = {
            14: "A",
            11: "J",
            12: "Q",
            13: "K",
        }
        if self.rank in ranks:
            rank = ranks[self.rank]
        else:
            rank = str(self.rank)
        return f"{rank}{suits[self.suit]}"

    def __eq__(self, other):
        return self.rank == other.rank and self.suit == other.suit

    def __lt__(self, other):
        return self.rank < other.rank

    def __hash__(self):
        return hash((self.rank, self.suit))

# %%
class CardDeck:
    def __init__(self):
        self.deck = [Card(rank, suit) for rank in range(2, 15) for suit in "SHDC"]
    def __repr__(self):
        return str(self.deck)
    def __len__(self):
        return len(self.deck)
    def __getitem__(self, position):
        return self.deck[position]
    def shuffleCards(self):
        import random
        random.shuffle(self.deck)
    def drawCards(self, n):
        return [self.deck.pop() for i in range(n)]
    def numCards(self):
        return len(self.deck)

# %%
class PokerHand:
    def __init__(self, cards):
        self.cards = cards
        self.cards.sort()
        self.cards.reverse()
        self.rank = self.getRank()
    def __repr__(self):
        return str(self.cards)
    def __len__(self):
        return len(self.cards)
    def __getitem__(self, position):
        return self.cards[position]
    def getRank(self):
        if self.isRoyalFlush():
            return 10
        elif self.isStraightFlush():
            return 9
        elif self.isFourOfAKind():
            return 8
        elif self.isFullHouse():
            return 7
        elif self.isFlush():
            return 6
        elif self.isStraight():
            return 5
        elif self.isThreeOfAKind():
            return 4
        elif self.isTwoPair():
            return 3
        elif self.isPair():
            return 2
        else:
            return 1.0 * self.cards[0].rank / 14
    def isRoyalFlush(self):
        if self.isStraightFlush() and self.cards[0].rank == 14:
            return True
        else:
            return False
    def isStraightFlush(self):
        if self.isFlush() and self.isStraight():
            return True
        else:
            return False
    def isFourOfAKind(self):
        if self.cards[0].rank == self.cards[3].rank or self.cards[1].rank == self.cards[4].rank:
            return True
        else:
            return False
    def isFullHouse(self):
        if self.isThreeOfAKind() and self.isPair():
            return True
        else:
            return False
    def isFlush(self):
        if self.cards[0].suit == self.cards[1].suit == self.cards[2].suit == self.cards[3].suit == self.cards[4].suit:
            return True
        else:
            return False
    def isStraight(self):
        if self.cards[0].rank == self.cards[1].rank + 1 == self.cards[2].rank + 2 == self.cards[3].rank + 3 == self.cards[4].rank + 4:
            return True
        else:
            return False
    def isThreeOfAKind(self):
        if self.cards[0].rank == self.cards[2].rank or self.cards[1].rank == self.cards[3].rank or self.cards[2].rank == self.cards[4].rank:
            return True
        else:
            return False
    def isTwoPair(self):
        if self.cards[0].rank == self.cards[1].rank and self.cards[2].rank == self.cards[3].rank:
            return True
        elif self.cards[0].rank == self.cards[1].rank and self.cards[3].rank == self.cards[4].rank:
            return True
        elif self.cards[1].rank == self.cards[2].rank and self.cards[3].rank == self.cards[4].rank:
            return True
        else:
            return False
    def isPair(self):
        if self.cards[0].rank == self.cards[1].rank or self.cards[1].rank == self.cards[2].rank or self.cards[2].rank == self.cards[3].rank or self.cards[3].rank == self.cards[4].rank:
            return True
        else:
            return False

# %%
from enum import Enum

class Action(Enum):
    FOLD = 0
    CALL = 1
    RAISE = 2
    CHECK = 3
    ALLIN = 4

    def __eq__(self, other):
        if isinstance(other, int):
            return self.value == other
        if isinstance(other, Action):
            return self.value == other.value
        return False

print(Action.FOLD == 0)  # Now this will print True
# Out:
# True

# %%
len(Action)
# Out:
# 5

# %%
class PokerGame:
    def __init__(self, players, smallBlind):
        self.deck = CardDeck()
        self.deck.shuffleCards()
        self.flop = []
        self.players = players
        self.smallBlind = smallBlind
        self.round = 0
        self.roundBet = 0
        self.pot = 0
        self.playersTurn = 0
        self.playersLeft = len(self.players)
        self.playersLeftToPlayInThisRound = len(self.players)
        print("num players", len(self.players))
        for player in self.players:
            if player.getBudget() == 0:
                print( "herer")
                player.folded = True
        self.nonFoldedPlayers = [player for player in self.players if player.folded == False]
        print(len(self.nonFoldedPlayers))
    
    def startRound(self):
        for player in self.players:
            player.resetRoundBet()
        self.roundBet = 0
        if self.round == 0:
            self.handleCards(2)
            self.makeInitialBets()
        elif self.round == 1:
            self.flopCards(3)
        elif self.round == 2:
            self.flopCards(1)
        elif self.round == 3:
            self.flopCards(1)
        self.playersLeftToPlayInThisRound = self.playersLeft
    
    def makeInitialBets(self):
        while(self.players[self.playersTurn].folded):
            self.playerTakeAction(self.players[self.playersTurn], Action.FOLD)
        if self.players[self.playersTurn].getBudget() <= self.smallBlind:
            self.playerTakeAction(self.players[self.playersTurn], Action.ALLIN)
        else:
            self.playerTakeAction(self.players[self.playersTurn], Action.RAISE, self.smallBlind)
        
        while(self.players[self.playersTurn].folded):
            self.playerTakeAction(self.players[self.playersTurn], Action.FOLD)
        if self.players[self.playersTurn].getBudget() <= self.smallBlind * 2:
            self.playerTakeAction(self.players[self.playersTurn], Action.ALLIN)
        else:
            self.playerTakeAction(self.players[self.playersTurn], Action.RAISE, self.smallBlind * 2)
    
    def finishRound(self):
        self.round += 1
        if self.isGameOver():
            self.getWinner()
    
    def getAmountToCall(self, player):
        return self.roundBet - player.roundBet
    
    def getPlayerActions(self, player): #all in fix needed
        if player.isFolded() == False:
            if player.isAllIn:
                return [Action.CHECK]
            if self.getAmountToCall(player) == 0:
                return [Action.FOLD, Action.RAISE, Action.ALLIN, Action.CHECK]
            elif player.getBudget() <= self.getAmountToCall(player):
                return [Action.FOLD, Action.ALLIN]
            else:
                return [Action.FOLD, Action.CALL, Action.RAISE, Action.ALLIN]
        else:
            return [Action.FOLD]
    
    def playerTakeAction(self, player, action, amount = 0):
        if self.playersTurn != self.players.index(player):
            raise ValueError
        if action == Action.FOLD:
            self.playerFold(player)
        elif action == Action.CALL:
            self.playerCall(player)
        elif action == Action.RAISE:
            self.playerRaise(player, amount)
        elif action == Action.CHECK:
            self.playerCheck(player)
        elif action == Action.ALLIN:
            self.playerAllIn(player, player.getBudget())
    
    def getCurrentPlayer(self):
        return self.players[self.playersTurn]

    def roundEnded(self):
        if self.playersLeftToPlayInThisRound == 0:
            return True
        else:
            return False
    
    def nextPlayer(self):
        self.playersTurn += 1
        if self.playersTurn == len(self.players):
            self.playersTurn = 0
        # if self.playersTurn == lastPlayer:
        #     self.finishRound()
    
    def playerRaise(self, player, amount):
        try:
            player.bet(amount)
            self.pot += amount
            self.roundBet = player.roundBet
            self.playersLeftToPlayInThisRound = len(self.players) - 1
            self.nextPlayer()
        except ValueError:
            print("Not enough money")
    
    def playerCall(self, player):
        try:
            amount = self.getAmountToCall(player)
            player.bet(amount)
            self.pot += amount
            self.playersLeftToPlayInThisRound -= 1
            self.nextPlayer()
        except ValueError:
            print("Not enough money")
    
    def playerCheck(self, player):
        try:
            if not player.isAllIn and self.getAmountToCall(player) != 0:
                raise ValueError
            self.playersLeftToPlayInThisRound -= 1
            self.nextPlayer()
        except ValueError:
            print("Not enough money")
    
    def playerAllIn(self, player, amount):
        try:
            player.bet(amount)
            self.pot += amount
            self.roundBet = max(player.roundBet, self.roundBet)
            self.playersLeftToPlayInThisRound = len(self.players) - 1
            self.nextPlayer()
        except ValueError:
            print("Not enough money")
    
    def playerFold(self, player):
        player.fold()
        self.playersLeftToPlayInThisRound -= 1
        if self.playersLeft != 1:
            self.nextPlayer()
    
    def getWinner(self):
        nonFoldedPlayers = [player for player in self.players if player.isFolded() == False]
        winner = nonFoldedPlayers[0]
        if len(nonFoldedPlayers) == 1:
            winner.budget += self.pot
            print(winner)
            return winner
        roundBets = [player.getBettedAmount() for player in self.players]
        while max(roundBets) != 0:
            winner = nonFoldedPlayers[0]
            winnerBestHand = self.getBestHand(winner)
            for player in nonFoldedPlayers:
                playerBestHand = self.getBestHand(player)
                if playerBestHand.rank > winnerBestHand.rank:
                    winner = player
                    winnerBestHand = playerBestHand
            winnerBet = winner.getBettedAmount()
            if winnerBet == max(roundBets):
                winner.budget += self.pot
                break
            else:
                for player in self.players:
                    amountWonOverThisPlayer = min(player.getBettedAmount(), winnerBet)
                    winner.budget += amountWonOverThisPlayer
                    player.bettedAmount -= amountWonOverThisPlayer
                    self.pot -= amountWonOverThisPlayer
            nonFoldedPlayers = [player for player in self.players if player.bettedAmount > 0]
            roundBets = [player.getBettedAmount() for player in self.players]
        return winner
    
    def getBestHand(self, player):
        import itertools
        bestHand = PokerHand(self.flop)
        for comb in itertools.combinations(player.hand + self.flop, 5):
            comb = list(comb)
            if PokerHand(comb).rank > bestHand.rank:
                bestHand = PokerHand(comb)
        return bestHand
    
    def isGameOver(self):
        if self.round == 4 or len([player for player in self.players if not player.isFolded()]) == 1:
            return True
        else:
            return False
    
    def handleCards(self, n):
        for player in self.players:
            player.hand = self.deck.drawCards(n)
    
    def flopCards(self, n):
        self.flop = self.flop + self.deck.drawCards(n)
    
    def getFlop(self):
        return self.flop
    
    def getPot(self):
        return self.pot

# %%
import random
class PokerUntilWinner:
    def __init__(self, players, smallBlind, buyin):
        self.players = players
        self.smallBlind = smallBlind
        self.buyin = buyin
        for player in self.players:
            player.budget = self.buyin
    
    def playUntilWinner(self):
        while self.areAllGamesOver() == False:
            print("New game started!")
            self.playRound()
            self.removePlayersWithNoMoney()
            self.resetPlayers()
            self.shiftPlayers()
            print("One game ended!")
        print("Game over! " + str(self.players[0].id) + " won!")

    def resetPlayers(self):
        for player in self.players:
            player.resetValues()

    def shiftPlayers(self):
        self.players.append(self.players.pop(0))
    
    def playRound(self):
        pokerGame = PokerGame(self.players, self.smallBlind)
        while pokerGame.isGameOver() == False:
            print("###################")
            print("New round started! " + str(pokerGame.round))
            pokerGame.startRound()
            while pokerGame.isGameOver() == False and pokerGame.roundEnded() == False:
                player = pokerGame.getCurrentPlayer()
                print("-------------------")
                print("player.id", player.id, "budget", player.budget)
                print("player.id", player.id, "betted amount total", player.bettedAmount)
                print(pokerGame.getFlop())
                print(pokerGame.getPot())
                print(player)
                actions = pokerGame.getPlayerActions(player)
                print("actions", actions)
                rand = random.randint(0, len(actions) - 1)
                action = actions[rand]
                print("action", action)
                if(action == Action.RAISE):
                    raiseAmount = random.randint(pokerGame.getAmountToCall(player), player.budget)
                    pokerGame.playerTakeAction(player, action, raiseAmount)
                else:
                    pokerGame.playerTakeAction(player, action)
                print("-------------------")
            print(pokerGame.pot)
            pokerGame.finishRound()
        print("Round ended! " + str(pokerGame.round))
        print("###################")
        for player in self.players:
            print("player with id:" , player.id, "has", player.budget, player.hand)

    def removePlayersWithNoMoney(self):
        players = []
        for player in self.players:
            if player.budget > 0:
                players.append(player)
        self.players = players
        print(self.players)
    
    def areAllGamesOver(self):
        return len(self.players) == 1

# %%
class PokerPlayer:
    def __init__(self, id, budget=0):
        self.id = id
        self.budget = budget
        self.bettedAmount = 0
        self.roundBet = 0
        self.hand = []
        self.folded = False
        self.isAllIn = False
    def getBudget(self):
        return self.budget
    def getBettedAmount(self):
        return self.bettedAmount
    def bet(self, amount):
        if(amount > self.budget):
            raise ValueError("You don't have enough money to bet that much!")
        self.roundBet += amount
        self.budget -= amount
        self.bettedAmount += amount
        if self.budget == 0:
            self.isAllIn = True
    def resetValues(self):
        self.bettedAmount = 0
        self.roundBet = 0
        self.hand = []
        self.folded = False
        self.isAllIn = False
    def resetRoundBet(self):
        self.roundBet = 0
    def isFolded(self):
        return self.folded
    def fold(self):
        self.folded = True
    def __repr__(self):
        return str(self.hand)
    def __len__(self):
        return len(self.hand)
    def __getitem__(self, position):
        return self.hand[position]

# %%
player1 = PokerPlayer(1)
player2 = PokerPlayer(2)
player3 = PokerPlayer(3)
player4 = PokerPlayer(4)
player5 = PokerPlayer(5)

poker = PokerUntilWinner([player1, player2, player3, player4, player5], 10, 100)
poker.playUntilWinner()
# Out:
# New game started!
# num players 5
# 5
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 100
# player.id 3 betted amount total 0
# []
# 30
# [9♦, 9♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 4 budget 100
# player.id 4 betted amount total 0
# []
# 116
# [5♣, 10♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 5 budget 100
# player.id 5 betted amount total 0
# []
# 214
# [A♥, 7♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 1 budget 90
# player.id 1 betted amount total 10
# []
# 214
# [6♦, 4♦]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 2 budget 80
# player.id 2 betted amount total 20
# []
# 302
# [3♥, 10♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 3 budget 14
# player.id 3 betted amount total 86
# []
# 382
# [9♦, 9♠]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 4 budget 2
# player.id 4 betted amount total 98
# []
# 396
# [5♣, 10♥]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 5 budget 100
# player.id 5 betted amount total 0
# []
# 398
# [A♥, 7♥]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 1 budget 2
# player.id 1 betted amount total 98
# []
# 398
# [6♦, 4♦]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 2 budget 0
# player.id 2 betted amount total 100
# []
# 398
# [3♥, 10♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 100
# []
# 398
# [9♦, 9♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 398
# ###################
# New round started! 1
# -------------------
# player.id 4 budget 0
# player.id 4 betted amount total 100
# [Q♦, 2♦, 4♣]
# 398
# [5♣, 10♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 100
# player.id 5 betted amount total 0
# [Q♦, 2♦, 4♣]
# 398
# [A♥, 7♥]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 1 budget 2
# player.id 1 betted amount total 98
# [Q♦, 2♦, 4♣]
# 398
# [6♦, 4♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 2 budget 0
# player.id 2 betted amount total 100
# [Q♦, 2♦, 4♣]
# 398
# [3♥, 10♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 100
# [Q♦, 2♦, 4♣]
# 398
# [9♦, 9♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 398
# ###################
# New round started! 2
# -------------------
# player.id 4 budget 0
# player.id 4 betted amount total 100
# [Q♦, 2♦, 4♣, 8♣]
# 398
# [5♣, 10♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 100
# player.id 5 betted amount total 0
# [Q♦, 2♦, 4♣, 8♣]
# 398
# [A♥, 7♥]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 1 budget 2
# player.id 1 betted amount total 98
# [Q♦, 2♦, 4♣, 8♣]
# 398
# [6♦, 4♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 2 budget 0
# player.id 2 betted amount total 100
# [Q♦, 2♦, 4♣, 8♣]
# 398
# [3♥, 10♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 100
# [Q♦, 2♦, 4♣, 8♣]
# 398
# [9♦, 9♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 398
# ###################
# New round started! 3
# -------------------
# player.id 4 budget 0
# player.id 4 betted amount total 100
# [Q♦, 2♦, 4♣, 8♣, 8♠]
# 398
# [5♣, 10♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 100
# player.id 5 betted amount total 0
# [Q♦, 2♦, 4♣, 8♣, 8♠]
# 398
# [A♥, 7♥]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 1 budget 2
# player.id 1 betted amount total 98
# [Q♦, 2♦, 4♣, 8♣, 8♠]
# 398
# [6♦, 4♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 2 budget 0
# player.id 2 betted amount total 100
# [Q♦, 2♦, 4♣, 8♣, 8♠]
# 398
# [3♥, 10♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 100
# [Q♦, 2♦, 4♣, 8♣, 8♠]
# 398
# [9♦, 9♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 398
# Round ended! 4
# ###################
# player with id: 1 has 2 [6♦, 4♦]
# player with id: 2 has 0 [3♥, 10♠]
# player with id: 3 has 398 [9♦, 9♠]
# player with id: 4 has 0 [5♣, 10♥]
# player with id: 5 has 100 [A♥, 7♥]
# [[6♦, 4♦], [9♦, 9♠], [A♥, 7♥]]
# One game ended!
# New game started!
# num players 3
# 3
# ###################
# New round started! 0
# -------------------
# player.id 1 budget 2
# player.id 1 betted amount total 0
# []
# 30
# [2♠, 6♦]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 3 budget 388
# player.id 3 betted amount total 10
# []
# 30
# [Q♦, 3♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 5 budget 80
# player.id 5 betted amount total 20
# []
# 418
# [6♠, 5♦]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 418
# [Q♦, 3♠]
# Round ended! 1
# ###################
# player with id: 3 has 418 [Q♦, 3♠]
# player with id: 5 has 80 [6♠, 5♦]
# player with id: 1 has 2 [2♠, 6♦]
# [[Q♦, 3♠], [6♠, 5♦], [2♠, 6♦]]
# One game ended!
# New game started!
# num players 3
# 3
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 418
# player.id 3 betted amount total 0
# []
# 12
# [K♥, A♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 5 budget 70
# player.id 5 betted amount total 10
# []
# 12
# [Q♥, 10♥]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.FOLD
# -------------------
# 12
# [9♦, 2♠]
# Round ended! 1
# ###################
# player with id: 5 has 70 [Q♥, 10♥]
# player with id: 1 has 12 [9♦, 2♠]
# player with id: 3 has 418 [K♥, A♥]
# [[Q♥, 10♥], [9♦, 2♠], [K♥, A♥]]
# One game ended!
# New game started!
# num players 3
# 3
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 70
# player.id 5 betted amount total 0
# []
# 30
# [4♣, 4♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 1 budget 2
# player.id 1 betted amount total 10
# []
# 62
# [6♦, 7♠]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 398
# player.id 3 betted amount total 20
# []
# 64
# [A♣, J♦]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 5 budget 38
# player.id 5 betted amount total 32
# []
# 64
# [4♣, 4♥]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 1 budget 0
# player.id 1 betted amount total 12
# []
# 102
# [6♦, 7♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 398
# player.id 3 betted amount total 20
# []
# 102
# [A♣, J♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# 102
# ###################
# New round started! 1
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 70
# [2♣, K♦, 7♥]
# 102
# [4♣, 4♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 1 budget 0
# player.id 1 betted amount total 12
# [2♣, K♦, 7♥]
# 102
# [6♦, 7♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 398
# player.id 3 betted amount total 20
# [2♣, K♦, 7♥]
# 102
# [A♣, J♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# 102
# ###################
# New round started! 2
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 70
# [2♣, K♦, 7♥, 9♦]
# 102
# [4♣, 4♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 1 budget 0
# player.id 1 betted amount total 12
# [2♣, K♦, 7♥, 9♦]
# 102
# [6♦, 7♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 398
# player.id 3 betted amount total 20
# [2♣, K♦, 7♥, 9♦]
# 102
# [A♣, J♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# 102
# ###################
# New round started! 3
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 70
# [2♣, K♦, 7♥, 9♦, 8♣]
# 102
# [4♣, 4♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 1 budget 0
# player.id 1 betted amount total 12
# [2♣, K♦, 7♥, 9♦, 8♣]
# 102
# [6♦, 7♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 398
# player.id 3 betted amount total 20
# [2♣, K♦, 7♥, 9♦, 8♣]
# 102
# [A♣, J♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# 102
# Round ended! 4
# ###################
# player with id: 1 has 36 [6♦, 7♠]
# player with id: 3 has 398 [A♣, J♦]
# player with id: 5 has 66 [4♣, 4♥]
# [[6♦, 7♠], [A♣, J♦], [4♣, 4♥]]
# One game ended!
# New game started!
# num players 3
# 3
# ###################
# New round started! 0
# -------------------
# player.id 1 budget 36
# player.id 1 betted amount total 0
# []
# 30
# [2♥, 5♦]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 3 budget 388
# player.id 3 betted amount total 10
# []
# 50
# [6♠, 6♦]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 5 budget 46
# player.id 5 betted amount total 20
# []
# 50
# [3♠, K♦]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 1 budget 16
# player.id 1 betted amount total 20
# []
# 96
# [2♥, 5♦]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 388
# player.id 3 betted amount total 10
# []
# 112
# [6♠, 6♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 66
# []
# 112
# [3♠, K♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 112
# ###################
# New round started! 1
# -------------------
# player.id 1 budget 0
# player.id 1 betted amount total 36
# [K♣, 3♣, Q♦]
# 112
# [2♥, 5♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 388
# player.id 3 betted amount total 10
# [K♣, 3♣, Q♦]
# 112
# [6♠, 6♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 66
# [K♣, 3♣, Q♦]
# 112
# [3♠, K♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 112
# ###################
# New round started! 2
# -------------------
# player.id 1 budget 0
# player.id 1 betted amount total 36
# [K♣, 3♣, Q♦, 10♠]
# 112
# [2♥, 5♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 388
# player.id 3 betted amount total 10
# [K♣, 3♣, Q♦, 10♠]
# 112
# [6♠, 6♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 66
# [K♣, 3♣, Q♦, 10♠]
# 112
# [3♠, K♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 112
# ###################
# New round started! 3
# -------------------
# player.id 1 budget 0
# player.id 1 betted amount total 36
# [K♣, 3♣, Q♦, 10♠, 2♣]
# 112
# [2♥, 5♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 388
# player.id 3 betted amount total 10
# [K♣, 3♣, Q♦, 10♠, 2♣]
# 112
# [6♠, 6♦]
# actions [<Action.FOLD: 0>]
# action Action.FOLD
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 66
# [K♣, 3♣, Q♦, 10♠, 2♣]
# 112
# [3♠, K♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 112
# Round ended! 4
# ###################
# player with id: 3 has 388 [6♠, 6♦]
# player with id: 5 has 112 [3♠, K♦]
# player with id: 1 has 0 [2♥, 5♦]
# [[6♠, 6♦], [3♠, K♦]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 102
# player.id 5 betted amount total 10
# []
# 30
# [J♠, J♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 30
# [9♣, 2♦]
# Round ended! 1
# ###################
# player with id: 5 has 102 [J♠, J♥]
# player with id: 3 has 398 [9♣, 2♦]
# [[J♠, J♥], [9♣, 2♦]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 388
# player.id 3 betted amount total 10
# []
# 30
# [5♦, 6♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 30
# [Q♠, Q♦]
# Round ended! 1
# ###################
# player with id: 3 has 388 [5♦, 6♠]
# player with id: 5 has 112 [Q♠, Q♦]
# [[5♦, 6♠], [Q♠, Q♦]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 102
# player.id 5 betted amount total 10
# []
# 30
# [J♥, 8♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 3 budget 368
# player.id 3 betted amount total 20
# []
# 56
# [7♥, K♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# 72
# ###################
# New round started! 1
# -------------------
# player.id 5 budget 76
# player.id 5 betted amount total 36
# [3♣, Q♠, 9♠]
# 72
# [J♥, 8♥]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 352
# player.id 3 betted amount total 36
# [3♣, Q♠, 9♠]
# 148
# [7♥, K♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 112
# [3♣, Q♠, 9♠]
# 500
# [J♥, 8♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 2
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 388
# [3♣, Q♠, 9♠, 4♦]
# 500
# [7♥, K♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 112
# [3♣, Q♠, 9♠, 4♦]
# 500
# [J♥, 8♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 3
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 388
# [3♣, Q♠, 9♠, 4♦, 8♣]
# 500
# [7♥, K♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 112
# [3♣, Q♠, 9♠, 4♦, 8♣]
# 500
# [J♥, 8♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# Round ended! 4
# ###################
# player with id: 5 has 224 [J♥, 8♥]
# player with id: 3 has 276 [7♥, K♣]
# [[J♥, 8♥], [7♥, K♣]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 266
# player.id 3 betted amount total 10
# []
# 30
# [2♣, K♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 30
# [7♠, 8♥]
# Round ended! 1
# ###################
# player with id: 3 has 266 [2♣, K♠]
# player with id: 5 has 234 [7♠, 8♥]
# [[2♣, K♠], [7♠, 8♥]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 224
# player.id 5 betted amount total 10
# []
# 30
# [Q♥, 5♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 3 budget 246
# player.id 3 betted amount total 20
# []
# 40
# [3♦, 10♣]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 5 budget 214
# player.id 5 betted amount total 20
# []
# 223
# [Q♥, 5♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 63
# player.id 3 betted amount total 203
# []
# 437
# [3♦, 10♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# 468
# ###################
# New round started! 1
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 234
# [Q♦, 6♦, 6♥]
# 468
# [Q♥, 5♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 32
# player.id 3 betted amount total 234
# [Q♦, 6♦, 6♥]
# 468
# [3♦, 10♣]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.FOLD
# -------------------
# 468
# [Q♥, 5♥]
# Round ended! 2
# ###################
# player with id: 5 has 468 [Q♥, 5♥]
# player with id: 3 has 32 [3♦, 10♣]
# [[Q♥, 5♥], [3♦, 10♣]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 22
# player.id 3 betted amount total 10
# []
# 30
# [6♠, 6♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 5 budget 448
# player.id 5 betted amount total 20
# []
# 52
# [K♣, A♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 32
# []
# 500
# [6♠, 6♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 1
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 468
# [9♣, 10♥, 9♥]
# 500
# [K♣, A♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 32
# [9♣, 10♥, 9♥]
# 500
# [6♠, 6♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 2
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 468
# [9♣, 10♥, 9♥, 7♥]
# 500
# [K♣, A♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 32
# [9♣, 10♥, 9♥, 7♥]
# 500
# [6♠, 6♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 3
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 468
# [9♣, 10♥, 9♥, 7♥, 2♣]
# 500
# [K♣, A♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 32
# [9♣, 10♥, 9♥, 7♥, 2♣]
# 500
# [6♠, 6♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# Round ended! 4
# ###################
# player with id: 3 has 64 [6♠, 6♥]
# player with id: 5 has 436 [K♣, A♣]
# [[6♠, 6♥], [K♣, A♣]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 426
# player.id 5 betted amount total 10
# []
# 30
# [K♠, K♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 3 budget 44
# player.id 3 betted amount total 20
# []
# 117
# [3♠, 5♠]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 117
# [K♠, K♥]
# Round ended! 1
# ###################
# player with id: 5 has 456 [K♠, K♥]
# player with id: 3 has 44 [3♠, 5♠]
# [[K♠, K♥], [3♠, 5♠]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 34
# player.id 3 betted amount total 10
# []
# 30
# [8♥, 8♦]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 5 budget 436
# player.id 5 betted amount total 20
# []
# 41
# [6♥, K♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 23
# player.id 3 betted amount total 21
# []
# 477
# [8♥, 8♦]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 456
# []
# 500
# [6♥, K♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 1
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 44
# [10♣, K♦, 7♥]
# 500
# [8♥, 8♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 456
# [10♣, K♦, 7♥]
# 500
# [6♥, K♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 2
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 44
# [10♣, K♦, 7♥, J♥]
# 500
# [8♥, 8♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 456
# [10♣, K♦, 7♥, J♥]
# 500
# [6♥, K♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 3
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 44
# [10♣, K♦, 7♥, J♥, 2♦]
# 500
# [8♥, 8♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 456
# [10♣, K♦, 7♥, J♥, 2♦]
# 500
# [6♥, K♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# Round ended! 4
# ###################
# player with id: 3 has 88 [8♥, 8♦]
# player with id: 5 has 412 [6♥, K♣]
# [[8♥, 8♦], [6♥, K♣]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 402
# player.id 5 betted amount total 10
# []
# 30
# [7♦, Q♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 68
# player.id 3 betted amount total 20
# []
# 432
# [A♦, A♣]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 432
# [7♦, Q♠]
# Round ended! 1
# ###################
# player with id: 5 has 432 [7♦, Q♠]
# player with id: 3 has 68 [A♦, A♣]
# [[7♦, Q♠], [A♦, A♣]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 58
# player.id 3 betted amount total 10
# []
# 30
# [3♠, J♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 5 budget 412
# player.id 5 betted amount total 20
# []
# 71
# [A♣, 6♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 71
# [3♠, J♥]
# Round ended! 1
# ###################
# player with id: 3 has 88 [3♠, J♥]
# player with id: 5 has 412 [A♣, 6♥]
# [[3♠, J♥], [A♣, 6♥]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 402
# player.id 5 betted amount total 10
# []
# 30
# [3♣, 3♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 3 budget 68
# player.id 3 betted amount total 20
# []
# 40
# [J♦, A♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.FOLD
# -------------------
# 40
# [3♣, 3♠]
# Round ended! 1
# ###################
# player with id: 5 has 432 [3♣, 3♠]
# player with id: 3 has 68 [J♦, A♠]
# [[3♣, 3♠], [J♦, A♠]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 58
# player.id 3 betted amount total 10
# []
# 30
# [4♣, A♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 5 budget 412
# player.id 5 betted amount total 20
# []
# 61
# [3♠, K♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 3 budget 27
# player.id 3 betted amount total 41
# []
# 213
# [4♣, A♠]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 213
# [3♠, K♣]
# Round ended! 1
# ###################
# player with id: 3 has 27 [4♣, A♠]
# player with id: 5 has 473 [3♠, K♣]
# [[4♣, A♠], [3♠, K♣]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 463
# player.id 5 betted amount total 10
# []
# 30
# [9♥, 4♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 3 budget 7
# player.id 3 betted amount total 20
# []
# 40
# [5♠, 6♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 40
# ###################
# New round started! 1
# -------------------
# player.id 5 budget 453
# player.id 5 betted amount total 20
# [Q♥, 3♦, 5♣]
# 40
# [9♥, 4♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.FOLD
# -------------------
# 40
# [5♠, 6♠]
# Round ended! 2
# ###################
# player with id: 5 has 453 [9♥, 4♠]
# player with id: 3 has 47 [5♠, 6♠]
# [[9♥, 4♠], [5♠, 6♠]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 37
# player.id 3 betted amount total 10
# []
# 30
# [5♥, 5♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 5 budget 433
# player.id 5 betted amount total 20
# []
# 67
# [3♠, 6♦]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# 94
# ###################
# New round started! 1
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 47
# [5♠, A♣, 7♦]
# 94
# [5♥, 5♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 406
# player.id 5 betted amount total 47
# [5♠, A♣, 7♦]
# 94
# [3♠, 6♦]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 47
# [5♠, A♣, 7♦]
# 308
# [5♥, 5♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 308
# ###################
# New round started! 2
# -------------------
# player.id 5 budget 192
# player.id 5 betted amount total 261
# [5♠, A♣, 7♦, 6♣]
# 308
# [3♠, 6♦]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 47
# [5♠, A♣, 7♦, 6♣]
# 500
# [5♥, 5♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 3
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 453
# [5♠, A♣, 7♦, 6♣, J♥]
# 500
# [3♠, 6♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 47
# [5♠, A♣, 7♦, 6♣, J♥]
# 500
# [5♥, 5♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# Round ended! 4
# ###################
# player with id: 3 has 94 [5♥, 5♣]
# player with id: 5 has 406 [3♠, 6♦]
# [[5♥, 5♣], [3♠, 6♦]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 396
# player.id 5 betted amount total 10
# []
# 30
# [9♥, 3♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 3 budget 74
# player.id 3 betted amount total 20
# []
# 40
# [K♣, 5♣]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 5 budget 386
# player.id 5 betted amount total 20
# []
# 114
# [9♥, 3♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 94
# []
# 329
# [K♣, 5♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 329
# ###################
# New round started! 1
# -------------------
# player.id 5 budget 171
# player.id 5 betted amount total 235
# [6♦, 5♥, 7♠]
# 329
# [9♥, 3♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 94
# [6♦, 5♥, 7♠]
# 500
# [K♣, 5♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 2
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 406
# [6♦, 5♥, 7♠, K♠]
# 500
# [9♥, 3♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 94
# [6♦, 5♥, 7♠, K♠]
# 500
# [K♣, 5♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 3
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 406
# [6♦, 5♥, 7♠, K♠, Q♣]
# 500
# [9♥, 3♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 94
# [6♦, 5♥, 7♠, K♠, Q♣]
# 500
# [K♣, 5♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# Round ended! 4
# ###################
# player with id: 5 has 312 [9♥, 3♠]
# player with id: 3 has 188 [K♣, 5♣]
# [[9♥, 3♠], [K♣, 5♣]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 178
# player.id 3 betted amount total 10
# []
# 30
# [8♣, 6♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 5 budget 292
# player.id 5 betted amount total 20
# []
# 77
# [7♦, 4♦]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 131
# player.id 3 betted amount total 57
# []
# 369
# [8♣, 6♣]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 312
# []
# 500
# [7♦, 4♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 1
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 188
# [K♥, Q♦, J♦]
# 500
# [8♣, 6♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 312
# [K♥, Q♦, J♦]
# 500
# [7♦, 4♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 2
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 188
# [K♥, Q♦, J♦, 3♥]
# 500
# [8♣, 6♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 312
# [K♥, Q♦, J♦, 3♥]
# 500
# [7♦, 4♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 3
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 188
# [K♥, Q♦, J♦, 3♥, J♠]
# 500
# [8♣, 6♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 312
# [K♥, Q♦, J♦, 3♥, J♠]
# 500
# [7♦, 4♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# Round ended! 4
# ###################
# player with id: 3 has 376 [8♣, 6♣]
# player with id: 5 has 124 [7♦, 4♦]
# [[8♣, 6♣], [7♦, 4♦]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 114
# player.id 5 betted amount total 10
# []
# 30
# [A♦, K♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 3 budget 356
# player.id 3 betted amount total 20
# []
# 40
# [K♦, 7♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 5 budget 104
# player.id 5 betted amount total 20
# []
# 71
# [A♦, K♥]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 325
# player.id 3 betted amount total 51
# []
# 175
# [K♦, 7♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 124
# []
# 255
# [A♦, K♥]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 255
# ###################
# New round started! 1
# -------------------
# player.id 3 budget 245
# player.id 3 betted amount total 131
# [8♠, 7♥, A♠]
# 255
# [K♦, 7♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.FOLD
# -------------------
# 255
# [A♦, K♥]
# Round ended! 2
# ###################
# player with id: 5 has 255 [A♦, K♥]
# player with id: 3 has 245 [K♦, 7♠]
# [[A♦, K♥], [K♦, 7♠]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 235
# player.id 3 betted amount total 10
# []
# 30
# [K♣, 4♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 5 budget 235
# player.id 5 betted amount total 20
# []
# 40
# [4♠, 9♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 225
# player.id 3 betted amount total 20
# []
# 275
# [K♣, 4♣]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 255
# []
# 500
# [4♠, 9♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 1
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 245
# [J♥, 6♠, 4♥]
# 500
# [K♣, 4♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 255
# [J♥, 6♠, 4♥]
# 500
# [4♠, 9♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 2
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 245
# [J♥, 6♠, 4♥, 5♣]
# 500
# [K♣, 4♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 255
# [J♥, 6♠, 4♥, 5♣]
# 500
# [4♠, 9♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 3
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 245
# [J♥, 6♠, 4♥, 5♣, K♥]
# 500
# [K♣, 4♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 255
# [J♥, 6♠, 4♥, 5♣, K♥]
# 500
# [4♠, 9♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# Round ended! 4
# ###################
# player with id: 3 has 490 [K♣, 4♣]
# player with id: 5 has 10 [4♠, 9♠]
# [[K♣, 4♣], [4♠, 9♠]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 10
# []
# 30
# [7♣, 9♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 470
# player.id 3 betted amount total 20
# []
# 30
# [J♠, K♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 30
# ###################
# New round started! 1
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 10
# [8♣, A♥, 7♠]
# 30
# [7♣, 9♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 470
# player.id 3 betted amount total 20
# [8♣, A♥, 7♠]
# 30
# [J♠, K♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 10
# [8♣, A♥, 7♠]
# 500
# [7♣, 9♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 2
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 490
# [8♣, A♥, 7♠, 6♥]
# 500
# [J♠, K♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 10
# [8♣, A♥, 7♠, 6♥]
# 500
# [7♣, 9♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# ###################
# New round started! 3
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 490
# [8♣, A♥, 7♠, 6♥, 8♥]
# 500
# [J♠, K♠]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 10
# [8♣, A♥, 7♠, 6♥, 8♥]
# 500
# [7♣, 9♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 500
# Round ended! 4
# ###################
# player with id: 5 has 20 [7♣, 9♣]
# player with id: 3 has 480 [J♠, K♠]
# [[7♣, 9♣], [J♠, K♠]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 470
# player.id 3 betted amount total 10
# []
# 30
# [Q♣, Q♦]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 20
# []
# 40
# [6♣, A♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 40
# ###################
# New round started! 1
# -------------------
# player.id 3 budget 460
# player.id 3 betted amount total 20
# [6♠, 3♥, 8♦]
# 40
# [Q♣, Q♦]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.FOLD
# -------------------
# 40
# [6♣, A♣]
# Round ended! 2
# ###################
# player with id: 3 has 460 [Q♣, Q♦]
# player with id: 5 has 40 [6♣, A♣]
# [[Q♣, Q♦], [6♣, A♣]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 30
# player.id 5 betted amount total 10
# []
# 30
# [Q♦, K♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 3 budget 440
# player.id 3 betted amount total 20
# []
# 40
# [J♦, 9♦]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 5 budget 20
# player.id 5 betted amount total 20
# []
# 361
# [Q♦, K♣]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 119
# player.id 3 betted amount total 341
# []
# 381
# [J♦, 9♦]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 381
# ###################
# New round started! 1
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 40
# [Q♠, 4♦, 2♣]
# 381
# [Q♦, K♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 119
# player.id 3 betted amount total 341
# [Q♠, 4♦, 2♣]
# 381
# [J♦, 9♦]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 5 budget 0
# player.id 5 betted amount total 40
# [Q♠, 4♦, 2♣]
# 447
# [Q♦, K♣]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 447
# ###################
# New round started! 2
# -------------------
# player.id 3 budget 53
# player.id 3 betted amount total 407
# [Q♠, 4♦, 2♣, 7♥]
# 447
# [J♦, 9♦]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.FOLD
# -------------------
# 447
# [Q♦, K♣]
# Round ended! 3
# ###################
# player with id: 5 has 447 [Q♦, K♣]
# player with id: 3 has 53 [J♦, 9♦]
# [[Q♦, K♣], [J♦, 9♦]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 43
# player.id 3 betted amount total 10
# []
# 30
# [4♣, 7♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 30
# [J♥, 2♠]
# Round ended! 1
# ###################
# player with id: 3 has 43 [4♣, 7♣]
# player with id: 5 has 457 [J♥, 2♠]
# [[4♣, 7♣], [J♥, 2♠]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 447
# player.id 5 betted amount total 10
# []
# 30
# [7♣, Q♦]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 30
# [6♦, A♥]
# Round ended! 1
# ###################
# player with id: 5 has 447 [7♣, Q♦]
# player with id: 3 has 53 [6♦, A♥]
# [[7♣, Q♦], [6♦, A♥]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 43
# player.id 3 betted amount total 10
# []
# 30
# [A♠, 4♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 5 budget 427
# player.id 5 betted amount total 20
# []
# 40
# [9♠, J♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.FOLD
# -------------------
# 40
# [A♠, 4♠]
# Round ended! 1
# ###################
# player with id: 3 has 73 [A♠, 4♠]
# player with id: 5 has 427 [9♠, J♠]
# [[A♠, 4♠], [9♠, J♠]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 417
# player.id 5 betted amount total 10
# []
# 30
# [10♣, A♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 30
# [6♠, 10♦]
# Round ended! 1
# ###################
# player with id: 5 has 417 [10♣, A♣]
# player with id: 3 has 83 [6♠, 10♦]
# [[10♣, A♣], [6♠, 10♦]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 73
# player.id 3 betted amount total 10
# []
# 30
# [10♣, 6♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.CALL
# -------------------
# -------------------
# player.id 5 budget 397
# player.id 5 betted amount total 20
# []
# 40
# [3♥, 9♣]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 63
# player.id 3 betted amount total 20
# []
# 437
# [10♣, 6♠]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 437
# [3♥, 9♣]
# Round ended! 1
# ###################
# player with id: 3 has 63 [10♣, 6♠]
# player with id: 5 has 437 [3♥, 9♣]
# [[10♣, 6♠], [3♥, 9♣]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 427
# player.id 5 betted amount total 10
# []
# 30
# [2♦, 3♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 3 budget 43
# player.id 3 betted amount total 20
# []
# 101
# [2♥, K♣]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 101
# [2♦, 3♠]
# Round ended! 1
# ###################
# player with id: 5 has 457 [2♦, 3♠]
# player with id: 3 has 43 [2♥, K♣]
# [[2♦, 3♠], [2♥, K♣]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 33
# player.id 3 betted amount total 10
# []
# 30
# [6♣, 9♣]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 30
# [10♠, A♦]
# Round ended! 1
# ###################
# player with id: 3 has 33 [6♣, 9♣]
# player with id: 5 has 467 [10♠, A♦]
# [[6♣, 9♣], [10♠, A♦]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 457
# player.id 5 betted amount total 10
# []
# 30
# [7♦, J♠]
# actions [<Action.FOLD: 0>, <Action.CALL: 1>, <Action.RAISE: 2>, <Action.ALLIN: 4>]
# action Action.ALLIN
# -------------------
# -------------------
# player.id 3 budget 13
# player.id 3 betted amount total 20
# []
# 487
# [8♣, 9♥]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 487
# [7♦, J♠]
# Round ended! 1
# ###################
# player with id: 5 has 487 [7♦, J♠]
# player with id: 3 has 13 [8♣, 9♥]
# [[7♦, J♠], [8♣, 9♥]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 3 budget 3
# player.id 3 betted amount total 10
# []
# 30
# [8♥, 10♣]
# actions [<Action.FOLD: 0>, <Action.ALLIN: 4>]
# action Action.FOLD
# -------------------
# 30
# [2♦, Q♥]
# Round ended! 1
# ###################
# player with id: 3 has 3 [8♥, 10♣]
# player with id: 5 has 497 [2♦, Q♥]
# [[8♥, 10♣], [2♦, Q♥]]
# One game ended!
# New game started!
# num players 2
# 2
# ###################
# New round started! 0
# -------------------
# player.id 5 budget 487
# player.id 5 betted amount total 10
# []
# 13
# [K♥, 6♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 3
# []
# 168
# [5♦, A♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 168
# ###################
# New round started! 1
# -------------------
# player.id 5 budget 332
# player.id 5 betted amount total 165
# [7♣, 3♥, K♦]
# 168
# [K♥, 6♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 3
# [7♣, 3♥, K♦]
# 380
# [5♦, A♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 380
# ###################
# New round started! 2
# -------------------
# player.id 5 budget 120
# player.id 5 betted amount total 377
# [7♣, 3♥, K♦, 4♣]
# 380
# [K♥, 6♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 3
# [7♣, 3♥, K♦, 4♣]
# 380
# [5♦, A♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 380
# ###################
# New round started! 3
# -------------------
# player.id 5 budget 120
# player.id 5 betted amount total 377
# [7♣, 3♥, K♦, 4♣, 9♠]
# 380
# [K♥, 6♠]
# actions [<Action.FOLD: 0>, <Action.RAISE: 2>, <Action.ALLIN: 4>, <Action.CHECK: 3>]
# action Action.RAISE
# -------------------
# -------------------
# player.id 3 budget 0
# player.id 3 betted amount total 3
# [7♣, 3♥, K♦, 4♣, 9♠]
# 496
# [5♦, A♦]
# actions [<Action.CHECK: 3>]
# action Action.CHECK
# -------------------
# 496
# Round ended! 4
# ###################
# player with id: 5 has 500 [K♥, 6♠]
# player with id: 3 has 0 [5♦, A♦]
# [[K♥, 6♠]]
# One game ended!
# Game over! 5 won!

# %%
# player1 = PokerPlayer(11, 1000)
# player2 = PokerPlayer(12, 1000)
# player3 = PokerPlayer(13, 1000)
# player4 = PokerPlayer(14, 1000)
# player5 = PokerPlayer(15, 1000)

# poker = PokerGame([player1, player2, player3, player4, player5], 10)

# while poker.isGameOver() == False:
#     print("New round started! " + str(poker.round))
#     poker.startRound()
#     while poker.roundEnded() == False:
#         player = poker.getCurrentPlayer()
#         print(poker.getFlop())
#         print(poker.getPot())
#         print(poker.getCurrentPlayer())
#         print(poker.getPlayerActions(poker.getCurrentPlayer()))
#         action = input("Action: ")
#         if action == "fold":
#             poker.playerTakeAction(player, Action.FOLD)
#         elif action == "call":
#             poker.playerTakeAction(player, Action.CALL)
#         elif action == "raise":
#             amount = int(input("Amount: "))
#             poker.playerTakeAction(player, Action.RAISE, amount)
#         elif action == "check":
#             poker.playerTakeAction(player, Action.CHECK)
#         elif action == "allin":
#             poker.playerTakeAction(player, Action.ALLIN)
#         else:
#             print("Invalid action")
#     poker.finishRound()
#     print("Round ended! " + str(poker.round))

# print("Game over!")
# print("The flop was: " + str(poker.flop))
# print("Player budgets:")
# for player in poker.players:
#     print("player with id:" , player.id, "has", player.budget, player.hand, "hand rank:", poker.getBestHand(player).rank)

# %%
cardDeck = CardDeck()
cardDeck.shuffleCards()
print(cardDeck)
# Out:
# [J♦, 6♠, 9♠, 3♦, 10♠, 3♥, 6♥, 8♣, K♥, Q♠, 10♥, 6♦, 4♣, 3♣, Q♥, 8♠, J♣, 9♣, 5♥, 7♥, 2♠, 8♥, 5♠, Q♣, 3♠, 7♣, A♠, 8♦, 6♣, A♦, 7♠, 2♥, 7♦, 4♦, 5♦, 4♠, 10♦, J♠, 9♥, A♣, 9♦, A♥, K♠, 10♣, Q♦, 5♣, 2♦, J♥, K♦, 2♣, K♣, 4♥]

# %%
card = Card(1, "S")
card2 = Card(1, "H")
print(card == card2)
# Out:
# False

# %%
import itertools
flop = [Card(7, "S"), Card(3, "S"), Card(4, "S"), Card(5, "S"), Card(6, "S")]
hand = [Card(5, "H"), Card(6, "H")]
bestHand = PokerHand(flop)
allHands = []
for comb in itertools.combinations(hand + flop, 5):
    comb = list(comb)
    allHands.append(PokerHand(comb))
    if PokerHand(comb).rank > bestHand.rank:
        bestHand = PokerHand(comb)
print(bestHand)
print(len(allHands))
# Out:
# [7♠, 6♠, 5♠, 4♠, 3♠]
# 21

# %%
import gym
import random
from gym import spaces
import numpy as np

class PokerEnv(gym.Env):
    def __init__(self, num_players, small_blind, buyin):
        super(PokerEnv, self).__init__()
        self.num_players = num_players
        self.small_blind = small_blind
        self.buyin = buyin
        self.players = [PokerPlayer(i, self.buyin) for i in range(self.num_players)]
        for player in self.players:
            player.budget = self.buyin
        # Observation space initialization
        self.observation_space = self._create_observation_space()

        # Action space initialization
        self.action_space = self._create_action_space()

    def restart(self, num_players, small_blind, buyin):
        self.num_players = num_players
        self.small_blind = small_blind
        self.buyin = buyin
        self.players = [PokerPlayer(i, self.buyin) for i in range(self.num_players)]
        for player in self.players:
            player.budget = self.buyin
        # Observation space initialization
        self.observation_space = self._create_observation_space()

        # Action space initialization
        self.action_space = self._create_action_space()
    
    def _create_observation_space(self):
        # Calculate initial observation space shape
        observation_space_shape = self._get_observation_space_shape()
        return spaces.Box(low=0, high=1, shape=(observation_space_shape,), dtype=np.float32)

    def _create_action_space(self):
        return spaces.Discrete(5)  # 0: fold, 1: call, 2: raise, 3: check, 4: all-in 
    # spaces.Tuple((
    #         spaces.Discrete(5),  # 0: fold, 1: call, 2: raise, 3: check, 4: all-in
    #         spaces.Box(low=0, high=1, shape=(1,), dtype=np.float32)  # Continuous action for raise amount
    #     ))
    def resetPlayers(self):
        for player in self.players:
            player.resetValues()

    def shiftPlayers(self):
        return

    def removePlayersWithNoMoney(self):
        # Remove players with no money from the game
        # self.players = [player for player in self.players if player.budget > 0]
        # Update the number of players in the observation space
        #self.observation_space = self._create_observation_space()
        return
    
    def areAllGamesOver(self):
        return len([player for player in self.players if player.budget > 0]) == 1

    def _get_observation_space_shape(self):
        # Budget, current bet, folded, all-in, hand (2 cards) for each player
        player_info_length = 4 + 2 * 2
        community_cards_length = 5 * 2  # Up to 5 community cards
        return self.num_players * player_info_length + community_cards_length + 3  # Pot size, current round, amount to call

    def reset(self):
        # self.removePlayersWithNoMoney()
        self.resetPlayers()
        # self.shiftPlayers()
        if self.areAllGamesOver():
            return self._get_state()
        self.round = PokerGame(self.players, self.small_blind)
        self.round.startRound()
        return self._get_state()
    
    def _get_default_hand(self):
        return [Card(2, 'S'), Card(2, 'H')]

    def _get_state(self):
        state = []
        for player in self.players:
            state.extend([player.budget / self.buyin, player.bettedAmount / self.buyin])
            state.append(1 if player.isFolded() else 0)
            state.append(1 if player.isAllIn else 0)
            hand = player.hand if len(player.hand) == 2 else self._get_default_hand()
            state.extend(self._encode_hand(hand))
            print("player", self.round.getCurrentPlayer())
            print("player.hand", player.hand)
        
        print("flop", self.round.getFlop())
        state.extend(self._encode_hand(self.round.getFlop()))
        state.extend([0] * (5 - len(self.round.getFlop())) * 2)
        
        state.append(self.round.getPot() / (self.buyin * self.num_players))
        state.append(self.round.round / 4)
        
        current_player = self.round.getCurrentPlayer()
        amount_to_call = self.round.getAmountToCall(current_player) / self.buyin
        state.append(amount_to_call)
        
        return np.array(state, dtype=np.float32)

    def _encode_hand(self, hand):
        card_values = []
        for card in hand:
            card_values.append(card.rank / 14)
            card_values.append(self._encode_suit(card.suit))
        return card_values
    
    def _encode_suit(self, suit):
        suit_dict = {'S': 0.25, 'H': 0.5, 'D': 0.75, 'C': 1.0}
        return suit_dict[suit]

    def getCurrentPlayer(self):
        return self.round.getCurrentPlayer()

    def step(self, action):
        if self.areAllGamesOver():
            return self._get_state(), self._calculate_reward, True, {}
        discrete_action = action
        # discrete_action, raise_fraction = action
        raise_fraction = 0.5  # Fraction of the budget to raise by
        current_player = self.round.getCurrentPlayer()
        actions = self.round.getPlayerActions(current_player)

        if discrete_action not in actions:
            discrete_action = actions[random.randrange(0, len(actions))]
        
        if discrete_action == Action.RAISE:  # If the action is 'raise'
            min_raise = self.round.getAmountToCall(current_player)
            max_raise = current_player.getBudget()
            raise_amount = min_raise + raise_fraction * (max_raise - min_raise)
            chosen_action = (Action.RAISE, raise_amount)
        else:
            chosen_action = discrete_action
        
        if isinstance(chosen_action, tuple):
            action_type, amount = chosen_action
            self.round.playerTakeAction(current_player, action_type, amount)
        else:
            self.round.playerTakeAction(current_player, chosen_action)
        
        if self.round.roundEnded():
            print("round ended")
            self.round.finishRound()
            # if self.round.isGameOver():
            #     return self._get_state(), self._calculate_reward(current_player), True, {}
            self.round.startRound()

        done = self.round.isGameOver() or self.areAllGamesOver()
        print("done", done)
        reward = self._calculate_reward(current_player)
        
        return self._get_state(), reward, done, {}

    def _calculate_reward(self, player):
        return player.getBudget()  # Simple reward based on the player's budget

    def render(self, mode='human'):
        pass

# %%
import sys
print(sys.version)
# Out:
# 3.11.7 (tags/v3.11.7:fa7a6f2, Dec  4 2023, 19:24:49) [MSC v.1937 64 bit (AMD64)]

# %%
import torch

if torch.cuda.is_available():
    print("CUDA is available. You can use GPU acceleration.")
else:
    print("CUDA is not available. You can only use CPU.")
# Out:
# CUDA is available. You can use GPU acceleration.

# %%
# %pip list
# Out:
# Package              Version
# -------------------- ------------
# asttokens            2.4.1
# cloudpickle          3.0.0
# colorama             0.4.6
# comm                 0.2.1
# contourpy            1.2.1
# cycler               0.12.1
# debugpy              1.8.0
# decorator            5.1.1
# executing            2.0.1
# Farama-Notifications 0.0.4
# filelock             3.14.0
# fonttools            4.51.0
# fsspec               2024.5.0
# git-filter-repo      2.38.0
# gym                  0.26.2
# gym-notices          0.0.8
# gymnasium            0.29.1
# intel-openmp         2021.4.0
# ipykernel            6.29.0
# ipython              8.21.0
# jedi                 0.19.1
# Jinja2               3.1.4
# jupyter_client       8.6.0
# jupyter_core         5.7.1
# kiwisolver           1.4.5
# MarkupSafe           2.1.5
# matplotlib           3.9.0
# matplotlib-inline    0.1.6
# mkl                  2021.4.0
# mpmath               1.3.0
# nest-asyncio         1.6.0
# networkx             3.3
# numpy                1.26.4
# packaging            23.2
# pandas               2.2.2
# parso                0.8.3
# pillow               10.3.0
# pip                  24.0
# platformdirs         4.2.0
# prompt-toolkit       3.0.43
# psutil               5.9.8
# pure-eval            0.2.2
# Pygments             2.17.2
# pyparsing            3.1.2
# python-dateutil      2.8.2
# pytz                 2024.1
# pywin32              306
# pyzmq                25.1.2
# setuptools           65.5.0
# Shimmy               2.0.0
# six                  1.16.0
# stable_baselines3    2.3.2
# stack-data           0.6.3
# sympy                1.12
# tbb                  2021.12.0
# torch                2.3.0+cu121
# torchaudio           2.3.0+cu121
# torchvision          0.18.0+cu121
# tornado              6.4
# traitlets            5.14.1
# typing_extensions    4.11.0
# tzdata               2024.1
# wcwidth              0.2.13
# Note: you may need to restart the kernel to use updated packages.

# %%
from gym import spaces
import numpy as np

class CustomActionWrapper(gym.ActionWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.action_space = spaces.Discrete(6)  # 0: fold, 1: call, 2-5: raise by different amounts

    def action(self, action):
        if action == Action.RAISE:
            raise_fraction = (action - 2) / 3  # Map action index to raise fraction
            return (2, raise_fraction)  # Raise action
        else:
            return (action, 0)  # Fold, call, allin, or check action

# %%
from stable_baselines3.common.callbacks import BaseCallback

class EarlyStoppingCallback(BaseCallback):
    def __init__(self, check_func, verbose=0):
        super(EarlyStoppingCallback, self).__init__(verbose)
        self.check_func = check_func

    def _on_step(self) -> bool:
        # Call the environment's areAllGamesOver function
        if self.check_func():
            print("Early stopping condition met. Training terminated.")
            return False  # Returning False stops training
        return True  # Continue training

# %%
import gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# Define the parameters
num_players = 4
small_blind = 10
buyin = 1000
num_episodes = 1000

# Create the environment
env = DummyVecEnv([lambda: PokerEnv(num_players, small_blind, buyin)])
early_stopping_callback = EarlyStoppingCallback(env.envs[0].areAllGamesOver)

# Define and train the agent
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=num_episodes, callback=early_stopping_callback)

# Save the trained model
model.save("poker_model")
print("Model saved successfully.")
model.env.envs[0].restart(num_players, small_blind, buyin)

# Evaluate the trained agent
total_rewards = [0 for _ in range(num_players)]
for _ in range(10):
    obs = env.reset()
    if env.envs[0].areAllGamesOver():
        break
    done = False
    while not done:
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)
        total_rewards[env.envs[0].getCurrentPlayer().id] += reward

print("Total rewards:", total_rewards)
print("Average total reward:", np.mean(total_rewards))

# Load the saved model
loaded_model = PPO.load("poker_model")

# Continue using the loaded model if needed
# Out:
# C:\Users\ugurkagan\AppData\Roaming\Python\Python311\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# num players 4
# 4
# player [3♣, 4♠]
# player.hand [5♣, Q♣]
# player [3♣, 4♠]
# player.hand [4♦, 5♠]
# player [3♣, 4♠]
# player.hand [3♣, 4♠]
# player [3♣, 4♠]
# player.hand [8♠, 10♦]
# flop []
# done False
# player [8♠, 10♦]
# player.hand [5♣, Q♣]
# player [8♠, 10♦]
# player.hand [4♦, 5♠]
# player [8♠, 10♦]
# player.hand [3♣, 4♠]
# player [8♠, 10♦]
# player.hand [8♠, 10♦]
# flop []
# done False
# player [5♣, Q♣]
# player.hand [5♣, Q♣]
# player [5♣, Q♣]
# player.hand [4♦, 5♠]
# player [5♣, Q♣]
# player.hand [3♣, 4♠]
# player [5♣, Q♣]
# player.hand [8♠, 10♦]
# flop []
# done False
# player [4♦, 5♠]
# player.hand [5♣, Q♣]
# player [4♦, 5♠]
# player.hand [4♦, 5♠]
# player [4♦, 5♠]
# player.hand [3♣, 4♠]
# player [4♦, 5♠]
# player.hand [8♠, 10♦]
# flop []
# done True
# player [3♣, 4♠]
# player.hand [5♣, Q♣]
# player [3♣, 4♠]
# player.hand [4♦, 5♠]
# player [3♣, 4♠]
# player.hand [3♣, 4♠]
# player [3♣, 4♠]
# player.hand [8♠, 10♦]
# flop []
# num players 4
# herer
# 3
# player [3♥, 6♠]
# player.hand [3♣, 5♣]
# player [3♥, 6♠]
# player.hand [2♦, J♣]
# player [3♥, 6♠]
# player.hand [3♥, 6♠]
# player [3♥, 6♠]
# player.hand [Q♥, 8♦]
# flop []
# done False
# player [Q♥, 8♦]
# player.hand [3♣, 5♣]
# player [Q♥, 8♦]
# player.hand [2♦, J♣]
# player [Q♥, 8♦]
# player.hand [3♥, 6♠]
# player [Q♥, 8♦]
# player.hand [Q♥, 8♦]
# flop []
# done False
# player [3♣, 5♣]
# player.hand [3♣, 5♣]
# player [3♣, 5♣]
# player.hand [2♦, J♣]
# player [3♣, 5♣]
# player.hand [3♥, 6♠]
# player [3♣, 5♣]
# player.hand [Q♥, 8♦]
# flop []
# done False
# player [2♦, J♣]
# player.hand [3♣, 5♣]
# player [2♦, J♣]
# player.hand [2♦, J♣]
# player [2♦, J♣]
# player.hand [3♥, 6♠]
# player [2♦, J♣]
# player.hand [Q♥, 8♦]
# flop []
# round ended
# done False
# player [3♥, 6♠]
# player.hand [3♣, 5♣]
# player [3♥, 6♠]
# player.hand [2♦, J♣]
# player [3♥, 6♠]
# player.hand [3♥, 6♠]
# player [3♥, 6♠]
# player.hand [Q♥, 8♦]
# flop [K♠, 6♦, Q♠]
# done False
# player [Q♥, 8♦]
# player.hand [3♣, 5♣]
# player [Q♥, 8♦]
# player.hand [2♦, J♣]
# player [Q♥, 8♦]
# player.hand [3♥, 6♠]
# player [Q♥, 8♦]
# player.hand [Q♥, 8♦]
# flop [K♠, 6♦, Q♠]
# done False
# player [3♣, 5♣]
# player.hand [3♣, 5♣]
# player [3♣, 5♣]
# player.hand [2♦, J♣]
# player [3♣, 5♣]
# player.hand [3♥, 6♠]
# player [3♣, 5♣]
# player.hand [Q♥, 8♦]
# flop [K♠, 6♦, Q♠]
# done True
# player [2♦, J♣]
# player.hand [3♣, 5♣]
# player [2♦, J♣]
# player.hand [2♦, J♣]
# player [2♦, J♣]
# player.hand [3♥, 6♠]
# player [2♦, J♣]
# player.hand [Q♥, 8♦]
# flop [K♠, 6♦, Q♠]
# num players 4
# herer
# 3
# player [5♣, 4♦]
# player.hand [7♦, K♠]
# player [5♣, 4♦]
# player.hand [5♥, 4♥]
# player [5♣, 4♦]
# player.hand [5♣, 4♦]
# player [5♣, 4♦]
# player.hand [2♥, Q♠]
# flop []
# done False
# player [2♥, Q♠]
# player.hand [7♦, K♠]
# player [2♥, Q♠]
# player.hand [5♥, 4♥]
# player [2♥, Q♠]
# player.hand [5♣, 4♦]
# player [2♥, Q♠]
# player.hand [2♥, Q♠]
# flop []
# done False
# player [7♦, K♠]
# player.hand [7♦, K♠]
# player [7♦, K♠]
# player.hand [5♥, 4♥]
# player [7♦, K♠]
# player.hand [5♣, 4♦]
# player [7♦, K♠]
# player.hand [2♥, Q♠]
# flop []
# done True
# player [5♥, 4♥]
# player.hand [7♦, K♠]
# player [5♥, 4♥]
# player.hand [5♥, 4♥]
# player [5♥, 4♥]
# player.hand [5♣, 4♦]
# player [5♥, 4♥]
# player.hand [2♥, Q♠]
# flop []
# player []
# player.hand []
# player []
# player.hand []
# player []
# player.hand []
# player []
# player.hand []
# flop []
# Early stopping condition met. Training terminated.
# Model saved successfully.
# num players 4
# 4
# player [K♦, J♠]
# player.hand [10♣, A♥]
# player [K♦, J♠]
# player.hand [9♦, 8♣]
# player [K♦, J♠]
# player.hand [K♦, J♠]
# player [K♦, J♠]
# player.hand [2♥, 4♣]
# flop []
# done False
# player [2♥, 4♣]
# player.hand [10♣, A♥]
# player [2♥, 4♣]
# player.hand [9♦, 8♣]
# player [2♥, 4♣]
# player.hand [K♦, J♠]
# player [2♥, 4♣]
# player.hand [2♥, 4♣]
# flop []
# done False
# player [10♣, A♥]
# player.hand [10♣, A♥]
# player [10♣, A♥]
# player.hand [9♦, 8♣]
# player [10♣, A♥]
# player.hand [K♦, J♠]
# player [10♣, A♥]
# player.hand [2♥, 4♣]
# flop []
# done False
# player [9♦, 8♣]
# player.hand [10♣, A♥]
# player [9♦, 8♣]
# player.hand [9♦, 8♣]
# player [9♦, 8♣]
# player.hand [K♦, J♠]
# player [9♦, 8♣]
# player.hand [2♥, 4♣]
# flop []
# round ended
# [K♦, J♠]
# done True
# player [K♦, J♠]
# player.hand [10♣, A♥]
# player [K♦, J♠]
# player.hand [9♦, 8♣]
# player [K♦, J♠]
# player.hand [K♦, J♠]
# player [K♦, J♠]
# player.hand [2♥, 4♣]
# flop [J♥, A♠, 6♣]
# num players 4
# 4
# player [J♦, 9♦]
# player.hand [K♥, 6♣]
# player [J♦, 9♦]
# player.hand [2♣, A♠]
# player [J♦, 9♦]
# player.hand [J♦, 9♦]
# player [J♦, 9♦]
# player.hand [8♦, 4♦]
# flop []
# num players 4
# 4
# player [5♦, A♣]
# player.hand [9♣, J♥]
# player [5♦, A♣]
# player.hand [7♣, K♣]
# player [5♦, A♣]
# player.hand [5♦, A♣]
# player [5♦, A♣]
# player.hand [10♦, 2♣]
# flop []
# done False
# player [10♦, 2♣]
# player.hand [9♣, J♥]
# player [10♦, 2♣]
# player.hand [7♣, K♣]
# player [10♦, 2♣]
# player.hand [5♦, A♣]
# player [10♦, 2♣]
# player.hand [10♦, 2♣]
# flop []
# done False
# player [9♣, J♥]
# player.hand [9♣, J♥]
# player [9♣, J♥]
# player.hand [7♣, K♣]
# player [9♣, J♥]
# player.hand [5♦, A♣]
# player [9♣, J♥]
# player.hand [10♦, 2♣]
# flop []
# done False
# player [7♣, K♣]
# player.hand [9♣, J♥]
# player [7♣, K♣]
# player.hand [7♣, K♣]
# player [7♣, K♣]
# player.hand [5♦, A♣]
# player [7♣, K♣]
# player.hand [10♦, 2♣]
# flop []
# done False
# player [5♦, A♣]
# player.hand [9♣, J♥]
# player [5♦, A♣]
# player.hand [7♣, K♣]
# player [5♦, A♣]
# player.hand [5♦, A♣]
# player [5♦, A♣]
# player.hand [10♦, 2♣]
# flop []
# done False
# player [10♦, 2♣]
# player.hand [9♣, J♥]
# player [10♦, 2♣]
# player.hand [7♣, K♣]
# player [10♦, 2♣]
# player.hand [5♦, A♣]
# player [10♦, 2♣]
# player.hand [10♦, 2♣]
# flop []
# done False
# player [9♣, J♥]
# player.hand [9♣, J♥]
# player [9♣, J♥]
# player.hand [7♣, K♣]
# player [9♣, J♥]
# player.hand [5♦, A♣]
# player [9♣, J♥]
# player.hand [10♦, 2♣]
# flop []
# done False
# player [7♣, K♣]
# player.hand [9♣, J♥]
# player [7♣, K♣]
# player.hand [7♣, K♣]
# player [7♣, K♣]
# player.hand [5♦, A♣]
# player [7♣, K♣]
# player.hand [10♦, 2♣]
# flop []
# done False
# player [5♦, A♣]
# player.hand [9♣, J♥]
# player [5♦, A♣]
# player.hand [7♣, K♣]
# player [5♦, A♣]
# player.hand [5♦, A♣]
# player [5♦, A♣]
# player.hand [10♦, 2♣]
# flop []
# done False
# player [10♦, 2♣]
# player.hand [9♣, J♥]
# player [10♦, 2♣]
# player.hand [7♣, K♣]
# player [10♦, 2♣]
# player.hand [5♦, A♣]
# player [10♦, 2♣]
# player.hand [10♦, 2♣]
# flop []
# round ended
# done False
# player [9♣, J♥]
# player.hand [9♣, J♥]
# player [9♣, J♥]
# player.hand [7♣, K♣]
# player [9♣, J♥]
# player.hand [5♦, A♣]
# player [9♣, J♥]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦]
# done False
# player [7♣, K♣]
# player.hand [9♣, J♥]
# player [7♣, K♣]
# player.hand [7♣, K♣]
# player [7♣, K♣]
# player.hand [5♦, A♣]
# player [7♣, K♣]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦]
# done False
# player [5♦, A♣]
# player.hand [9♣, J♥]
# player [5♦, A♣]
# player.hand [7♣, K♣]
# player [5♦, A♣]
# player.hand [5♦, A♣]
# player [5♦, A♣]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦]
# done False
# player [10♦, 2♣]
# player.hand [9♣, J♥]
# player [10♦, 2♣]
# player.hand [7♣, K♣]
# player [10♦, 2♣]
# player.hand [5♦, A♣]
# player [10♦, 2♣]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦]
# round ended
# done False
# player [9♣, J♥]
# player.hand [9♣, J♥]
# player [9♣, J♥]
# player.hand [7♣, K♣]
# player [9♣, J♥]
# player.hand [5♦, A♣]
# player [9♣, J♥]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦, K♦]
# done False
# player [7♣, K♣]
# player.hand [9♣, J♥]
# player [7♣, K♣]
# player.hand [7♣, K♣]
# player [7♣, K♣]
# player.hand [5♦, A♣]
# player [7♣, K♣]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦, K♦]
# done False
# player [5♦, A♣]
# player.hand [9♣, J♥]
# player [5♦, A♣]
# player.hand [7♣, K♣]
# player [5♦, A♣]
# player.hand [5♦, A♣]
# player [5♦, A♣]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦, K♦]
# done False
# player [10♦, 2♣]
# player.hand [9♣, J♥]
# player [10♦, 2♣]
# player.hand [7♣, K♣]
# player [10♦, 2♣]
# player.hand [5♦, A♣]
# player [10♦, 2♣]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦, K♦]
# round ended
# done False
# player [9♣, J♥]
# player.hand [9♣, J♥]
# player [9♣, J♥]
# player.hand [7♣, K♣]
# player [9♣, J♥]
# player.hand [5♦, A♣]
# player [9♣, J♥]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦, K♦, A♥]
# done False
# player [7♣, K♣]
# player.hand [9♣, J♥]
# player [7♣, K♣]
# player.hand [7♣, K♣]
# player [7♣, K♣]
# player.hand [5♦, A♣]
# player [7♣, K♣]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦, K♦, A♥]
# done False
# player [5♦, A♣]
# player.hand [9♣, J♥]
# player [5♦, A♣]
# player.hand [7♣, K♣]
# player [5♦, A♣]
# player.hand [5♦, A♣]
# player [5♦, A♣]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦, K♦, A♥]
# done False
# player [10♦, 2♣]
# player.hand [9♣, J♥]
# player [10♦, 2♣]
# player.hand [7♣, K♣]
# player [10♦, 2♣]
# player.hand [5♦, A♣]
# player [10♦, 2♣]
# player.hand [10♦, 2♣]
# flop [3♠, Q♣, Q♦, K♦, A♥]
# round ended
# done True
# player [9♣, J♥]
# player.hand [9♣, J♥]
# player [9♣, J♥]
# player.hand [7♣, K♣]
# player [9♣, J♥]
# player.hand [5♦, A♣]
# player [9♣, J♥]
# player.hand [10♦, 2♣]
# flop [A♥, K♦, Q♦, Q♣, 3♠]
# num players 4
# 4
# player [9♥, 10♦]
# player.hand [6♠, 7♥]
# player [9♥, 10♦]
# player.hand [8♥, 6♣]
# player [9♥, 10♦]
# player.hand [9♥, 10♦]
# player [9♥, 10♦]
# player.hand [3♠, 4♠]
# flop []
# num players 4
# 4
# player [7♥, 8♥]
# player.hand [A♦, 9♦]
# player [7♥, 8♥]
# player.hand [K♥, 10♣]
# player [7♥, 8♥]
# player.hand [7♥, 8♥]
# player [7♥, 8♥]
# player.hand [2♠, 6♠]
# flop []
# done False
# player [2♠, 6♠]
# player.hand [A♦, 9♦]
# player [2♠, 6♠]
# player.hand [K♥, 10♣]
# player [2♠, 6♠]
# player.hand [7♥, 8♥]
# player [2♠, 6♠]
# player.hand [2♠, 6♠]
# flop []
# done False
# player [A♦, 9♦]
# player.hand [A♦, 9♦]
# player [A♦, 9♦]
# player.hand [K♥, 10♣]
# player [A♦, 9♦]
# player.hand [7♥, 8♥]
# player [A♦, 9♦]
# player.hand [2♠, 6♠]
# flop []
# done False
# player [K♥, 10♣]
# player.hand [A♦, 9♦]
# player [K♥, 10♣]
# player.hand [K♥, 10♣]
# player [K♥, 10♣]
# player.hand [7♥, 8♥]
# player [K♥, 10♣]
# player.hand [2♠, 6♠]
# flop []
# done False
# player [7♥, 8♥]
# player.hand [A♦, 9♦]
# player [7♥, 8♥]
# player.hand [K♥, 10♣]
# player [7♥, 8♥]
# player.hand [7♥, 8♥]
# player [7♥, 8♥]
# player.hand [2♠, 6♠]
# flop []
# done False
# player [2♠, 6♠]
# player.hand [A♦, 9♦]
# player [2♠, 6♠]
# player.hand [K♥, 10♣]
# player [2♠, 6♠]
# player.hand [7♥, 8♥]
# player [2♠, 6♠]
# player.hand [2♠, 6♠]
# flop []
# round ended
# done False
# player [A♦, 9♦]
# player.hand [A♦, 9♦]
# player [A♦, 9♦]
# player.hand [K♥, 10♣]
# player [A♦, 9♦]
# player.hand [7♥, 8♥]
# player [A♦, 9♦]
# player.hand [2♠, 6♠]
# flop [8♦, A♣, 5♦]
# done True
# player [K♥, 10♣]
# player.hand [A♦, 9♦]
# player [K♥, 10♣]
# player.hand [K♥, 10♣]
# player [K♥, 10♣]
# player.hand [7♥, 8♥]
# player [K♥, 10♣]
# player.hand [2♠, 6♠]
# flop [8♦, A♣, 5♦]
# num players 4
# herer
# 3
# player [4♥, 10♥]
# player.hand [9♣, 10♣]
# player [4♥, 10♥]
# player.hand [6♣, 3♦]
# player [4♥, 10♥]
# player.hand [4♥, 10♥]
# player [4♥, 10♥]
# player.hand [2♣, 5♥]
# flop []
# num players 4
# herer
# 3
# player [6♠, K♥]
# player.hand [A♦, 5♠]
# player [6♠, K♥]
# player.hand [9♠, 4♠]
# player [6♠, K♥]
# player.hand [6♠, K♥]
# player [6♠, K♥]
# player.hand [10♦, A♣]
# flop []
# done False
# player [10♦, A♣]
# player.hand [A♦, 5♠]
# player [10♦, A♣]
# player.hand [9♠, 4♠]
# player [10♦, A♣]
# player.hand [6♠, K♥]
# player [10♦, A♣]
# player.hand [10♦, A♣]
# flop []
# done False
# player [A♦, 5♠]
# player.hand [A♦, 5♠]
# player [A♦, 5♠]
# player.hand [9♠, 4♠]
# player [A♦, 5♠]
# player.hand [6♠, K♥]
# player [A♦, 5♠]
# player.hand [10♦, A♣]
# flop []
# done True
# player [9♠, 4♠]
# player.hand [A♦, 5♠]
# player [9♠, 4♠]
# player.hand [9♠, 4♠]
# player [9♠, 4♠]
# player.hand [6♠, K♥]
# player [9♠, 4♠]
# player.hand [10♦, A♣]
# flop []
# player []
# player.hand []
# player []
# player.hand []
# player []
# player.hand []
# player []
# player.hand []
# flop []
# player []
# player.hand []
# player []
# player.hand []
# player []
# player.hand []
# player []
# player.hand []
# flop []
# Total rewards: [array([2020.], dtype=float32), array([1940.], dtype=float32), array([7070.], dtype=float32), array([6180.], dtype=float32)]
# Average total reward: 4302.5
